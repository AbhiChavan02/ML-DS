# %% [markdown]
# ##### Introduction to Functions

# %% [markdown]
# A function is block of code that performs a specific task. Functions help in organizing code, resuing code, and imporving readiablity.

# %%
## Syntax
def function_name(parameters):
    """Docstring"""
    # Function body
    return expression

# %%
print("Hello")
