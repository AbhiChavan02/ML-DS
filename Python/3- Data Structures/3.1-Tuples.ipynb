# %%
## Creating a Tuple
empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1,2,3,4,5])
numbers
# Out:
# (1, 2, 3, 4, 5)

# %%
mixed_tuple = (1, "Hello", 3.14, True)
print(mixed_tuple)
# Out:
# (1, 'Hello', 3.14, True)

# %%
## Accessing Tuple Elements
numbers
# Out:
# (1, 2, 3, 4, 5)

# %%
numbers[0]
