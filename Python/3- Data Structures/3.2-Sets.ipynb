# %%
# Create a Set
my_set = {1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_empty_set = set()
print(type(my_empty_set))
# Out:
# <class 'set'>

# %%
my_set = set([1,2,3,4,5])
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_empty_set = set([1,2,3,6,5,4,5,6])
print(my_empty_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
## Basic Set Operations

#1. Adding Elements
my_set.add(6)
print(my_set)
my_set.add(6)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}

# %%
#2. Removing Elements from a set
my_set.remove(3)
print(my_set)
# Out:
# {1, 2, 4, 5, 6}

# %%
my_set.remove(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 my_set.remove(10)
#
# KeyError: 10

# %%
#3. Discard Element - Remove an element from set if it is a member otherwise not give us a error
my_set.discard(11)
print(my_set)
# Out:
# {1, 2, 4, 5, 6}

# %%
#4. Pop method - First in first out. whatever element is first inserted that element only get removed
removed_element = my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 1
# {2, 4, 5, 6}

# %%
#5. Clear - clear all the elements
my_set.clear()
print(my_set)
# Out:
# set()

# %%
## Set membership test
my_set = {1,2,3,4,5}
print(3 in my_set)
print(10 in my_set)
# Out:
# True
# False

# %% [markdown]
# #### Mathematical Operations

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

### Union
union_set = set1.union(set2)
print(union_set)

### Intersection
intersection_set = set1.intersection(set2)
print(intersection_set)

### Intersection Update
set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {4, 5, 6}

# %%
set1 = {1,2,3,4,5,6}
set2 = {4,5,6,7,8,9}

### Difference
print(set1.difference(set2))
# Out:
# {1, 2, 3}
