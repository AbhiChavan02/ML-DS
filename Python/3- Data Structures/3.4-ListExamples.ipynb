# %% [markdown]
# ##### Real World Examples using List and Python

# %% [markdown]
# List are one of the most commonly used data stuructures in Python, beacuse of versatility and ease to use.

# %% [markdown]
# 1. Manage a To Do List - Create a To Do List to keep track of tasks.

# %%
to_do_list = ["Buy Groceries","Clean the house","Pay Bills"]

## Adding to Task
to_do_list.append("Schedule Meeting")
to_do_list.append("Go for a Run")

## Removing a completed task
to_do_list.remove("Clean the house")

## Checking if a task is in the list
if "Pay Bills" in to_do_list:
    print("Don't forget to pay the utility bill")

print("To Do List remaining")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Don't forget to pay the utility bill
# To Do List remaining
# -Buy Groceries
# -Pay Bills
# -Schedule Meeting
# -Go for a Run

# %% [markdown]
# 2. Organizing Student marks - Create a list to store and calculate average marks for students

# %%
## Organizing student grades
grades = [85, 92, 78, 90, 88]

## Adding a new grades
grades.append(95)

## Calculate the average grade
average_grade = sum(grades) / len(grades)
print(f"Average Grade: {average_grade:.2f}")

# Finding the highest and lowest grades
highest_grade = max(grades)
lowest_grade = min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grades: {lowest_grade}")
# Out:
# Average Grade: 88.00
# Highest Grade: 95
# Lowest Grades: 78

# %% [markdown]
# 3. Managing An Inventory - Use a list to manage inventory items in a store.

# %%
## Managing an Inventory
inventory = ["Apples", "Banana", "Oranges", "Grapes"]

## Adding a new item
inventory.append("Pomegranate")

## Removing an item that is out of stocks
inventory.remove("Banana")

## Checking if an item is in stock
item = "Oranges"
if item in inventory:
    print(f"{item} are in stock.")
else:
    print(f"{item} are out of stock.")

## Printing the inventory
print("Inventory List:")
for item in inventory:
    print(f"- {item}")
# Out:
# Oranges are in stock.
# Inventory List:
# - Apples
# - Oranges
# - Grapes
# - Pomegranate

# %% [markdown]
# 4. Collecting User Feedback - Use a list to collet and analyze user feedback.

# %%
## Collecting user feedback
feedback = ["Great Service!", "Very Satisfied", "Could be Better", "Excellent Experience"]

## Adding new Feedback
feedback.append("Not happy with the Service")

## Counting specific feedback
positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower())
print(f"Positive Feedback Count: {positive_feedback_count}")

## Printing all Feedbacks
print("User Feedback:")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count: 2
# User Feedback:
# - Great Service!
# - Very Satisfied
# - Could be Better
# - Excellent Experience
# - Not happy with the Service
